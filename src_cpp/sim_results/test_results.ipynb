# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('sim_results_5_4_3_3_3_1_1_5_5_3_3_3_1_1_cardata.txt', names =['tiempo']+[f'par{i}' for i in range(20)],sep = ' ', index_col=False)

# %%
data['par10'].value_counts()
# Out:
# 5    78616
# 6    73429
# 4    18818
# 2    12914
# 1    12326
# 0     9986
# 3     9215
# Name: par10, dtype: int64

# %%
#mask = data['id']==499
sns.scatterplot(data, x = 'tiempo', y = 'par0', hue = 'par1')
# Out:
# <Axes: xlabel='tiempo', ylabel='par0'>

# %%
#mask = data['id']==499
sns.scatterplot(data, x = 'tiempo', y = 'par0', hue = 'par1')
# Out:
# <Axes: xlabel='tiempo', ylabel='par0'>

# %%
data['par']

# %%
data[data['tiempo']==data['tiempo'].max()]['par13']
# Out:
# 121822    479
# 121823    480
# 121824    481
# 121825    482
# 121826    483
# 121827    484
# 121828    486
# 121829    485
# 121830    487
# 121831    488
# 121832    489
# 121833    490
# 121834    491
# 121835    492
# 121836    493
# 121837    494
# 121838    495
# 121839    496
# 121840    497
# 121841    498
# 121842    499
# Name: par13, dtype: int64

# %%
sns.scatterplot(data[data['par13']==498], x = 'tiempo', y = 'par0', hue = 'par1')
# Out:
# <Axes: xlabel='tiempo', ylabel='par0'>

# %%
data[data['par13']==499].to_csv('test.csv')

# %%
EL = np.loadtxt('../../conf/EL_door_5_dir_0_or_0.txt')
Lanes = np.loadtxt('../../conf/lanes_door_5_dir_0_or_0.txt')

# %%
EL[967-27][0]
# Out:
# 242.0

# %%
Lanes[1172-27]
# Out:
# array([1., 0.])
