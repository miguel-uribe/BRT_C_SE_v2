# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('sim_results_5_4_3_3_3_1_1_5_5_3_3_3_1_1_cardata.txt', names =['tiempo']+[f'par{i}' for i in range(20)],sep = ' ', index_col=False)

# %%
df['tiempo'].max()
# Out:
# np.int64(10799)

# %% [markdown]
# # looking for zig zag

# %%
for id,test in df.groupby('par13'):
    test['change']=np.abs(test['par1']-test['par1'].shift()).rolling(10).sum()
    if test['change'].max()>1:
        print(f'carro {id} está zigzagueando en t {test[test['change']==test['change'].max()][['tiempo','par10']]}')
# Out:
# carro 458 está zigzagueando en t        tiempo  par10
# 81683    3029     14
# carro 469 está zigzagueando en t         tiempo  par10
# 150224    6048     14
# 150240    6049     14
# carro 472 está zigzagueando en t        tiempo  par10
# 55377    2265      8
# 55411    2266      8
# 55446    2267      8
# 55481    2268      8
# 55516    2269      8
# 55552    2270      8
# 55588    2271      8
# 55624    2272      8
# carro 480 está zigzagueando en t        tiempo  par10
# 15930     819      8
# 15959     820      8
# 15988     821      8
# 16017     822      8
# 16047     823      8
# 16077     824      8
# 16108     825      8
# 16139     826      8
# 16170     827      8
# carro 486 está zigzagueando en t         tiempo  par10
# 267250   10722     14
# 267278   10723     14
# 267306   10724     14
# 267334   10725     14
# 267361   10726     14
# 267389   10727     14
# 267417   10728     14
# 267445   10729     14
# 267474   10730     14
# carro 495 está zigzagueando en t         tiempo  par10
# 138383    5611      8

# %%
mask = (df['tiempo']>2260) & (df['par13']==472) & (df['par10']==8)
df[mask].head(50)
# Out:
#        tiempo  par0  par1  par2  par3  par4  par5  par6     par7  par8  ...  \
# 55241    2261  2493     0    17    94     0     0     0     2753     1  ...
# 55275    2262  2509     0    16    94     0     0     0     2753     1  ...
# 55309    2263  2526     1    17   244  1000 -1000     0     2753     1  ...
# 55343    2264  2543     1    17    93    93  -102    17     2753     1  ...
# 55377    2265  2560     0    17   175   248  -102    17     2753     1  ...
# 55411    2266  2577     0    17   158    74 -1000     0     2753     1  ...
# 55446    2267  2593     0    16   141    65 -1000     0     2753     1  ...
# 55481    2268  2610     0    17   125    57 -1000     0     2753     1  ...
# 55516    2269  2627     0    17   108    44 -1000     0     2753     1  ...
# 55552    2270  2644     0    17    91    27 -1000     0     2753     1  ...
# 55588    2271  2661     0    17    74    10 -1000     0     2753     1  ...
# 55624    2272  2678     0    17    57    -7 -1000     0     2753     1  ...
# 55660    2273  2695     0    17    40   -24 -1000     0     2753     1  ...
# 55695    2274  2712     0    17    23  1000    13     0     2753     1  ...
# 55730    2275  2720     1     8    41  1000    -4     0     2753     1  ...
# 55765    2276  2728     1     8    33   254   -95    17     2753     1  ...
# 55800    2277  2736     1     8    25   263   -86    17     2753     1  ...
# 55834    2278  2744     1     8    17   263   -86    17     2753     1  ...
# 55868    2279  2751     1     7     9   263   -86    17     2753     1  ...
# 55902    2280  2752     1     1     2   263   -86    17     2753     1  ...
# 55936    2281  2752     1     0     1   263   -86    17     2753     1  ...
# 55970    2282  2753     1     0     1   263   -86    17  1000000    -1  ...
# 56003    2283  2753     1     0  1000   263   -86    17  1000000    -1  ...
# 56036    2284  2753     1     0  1000   263   -86    17  1000000    -1  ...
# 56069    2285  2753     1     0  1000   263   -86    17  1000000    -1  ...
# 56102    2286  2753     1     0  1000   263   -86    17  1000000    -1  ...
# 56135    2287  2753     1     0  1000   263   -86    17  1000000    -1  ...
# 56168    2288  2753     1     0  1000   263   -86    17  1000000    -1  ...
# 56201    2289  2753     1     0  1000   263   -86    17  1000000    -1  ...
# 56233    2290  2753     1     0  1000   263   -86    17  1000000    -1  ...
# 56265    2291  2753     1     0  1000   263   -86    17  1000000    -1  ...
# 56297    2292  2753     1     0  1000   263   -86    17  1000000    -1  ...
# 56329    2293  2753     1     0  1000   263   -86    17  1000000    -1  ...
# 56361    2294  2753     1     0  1000   263   -86    17  1000000    -1  ...
# 56393    2295  2753     1     0  1000   263   -86    17  1000000    -1  ...
# 56425    2296  2753     1     0  1000   263   -86    17  1000000    -1  ...
# 56457    2297  2753     1     0  1000   263   -86    17  1000000    -1  ...
# 56490    2298  2753     1     0  1000   263   -86    17  1000000    -1  ...
# 56523    2299  2753     1     0  1000   263   -86    17  1000000    -1  ...
# 56556    2300  2753     1     0  1000   263   -86    17  1000000    -1  ...
# 56589    2301  2753     1     0  1000   263   -86    17  1000000    -1  ...
# 56622    2302  2753     1     0  1000   263   -86    17  1000000    -1  ...
# 56655    2303  2753     1     0  1000   263   -86    17  1000000    -1  ...
# 56688    2304  2753     1     0  1000   263   -86    17  1000000    -1  ...
# 56722    2305  2753     1     0  1000   263   -86    17  1000000    -1  ...
# 56756    2306  2753     1     0  1000   263   -86    17  1000000    -1  ...
# 56789    2307  2753     1     0  1000   263   -86    17  1000000    -1  ...
# 56822    2308  2753     1     0  1000   263   -86    17  1000000    -1  ...
# 56855    2309  2753     1     0  1000   263   -86    17  1000000    -1  ...
# 56888    2310  2753     1     0  1000   263   -86    17  1000000    -1  ...
#
#        par10  par11  par12  par13  par14  par15  par16  par17  par18  par19
# 55241      8      0      0    472   2197     27      5      1      1      0
# 55275      8      0      0    472   2197     27      5      1      1      0
# 55309      8      0      0    472   2197     27      5      1      1      0
# 55343      8      0      0    472   2197     27      5      1      1      0
# 55377      8      0      0    472   2197     27      5      1      1      0
# 55411      8      0      0    472   2197     27      5      1      1      0
# 55446      8      0      0    472   2197     27      5      1      1      0
# 55481      8      0      0    472   2197     27      5      1      1      0
# 55516      8      0      0    472   2197     27      5      1      1      0
# 55552      8      0      0    472   2197     27      5      1      1      0
# 55588      8      0      0    472   2197     27      5      1      1      0
# 55624      8      0      0    472   2197     27      5      1      1      0
# 55660      8      0      0    472   2197     27      5      1      1      1
# 55695      8      0      0    472   2197     27      5      1      1      1
# 55730      8      0      0    472   2197     27      5      1      1      0
# 55765      8      0      0    472   2197     27      5      1      1      0
# 55800      8      0      0    472   2197     27      5      1      1      0
# 55834      8      0      0    472   2197     27      5      1      1      0
# 55868      8      0      0    472   2197     27      5      1      1      0
# 55902      8      0      0    472   2197     27      5      1      1      0
# 55936      8      0      0    472   2197     27      5      1      1      0
# 55970      8      0     32    472   2197     27      5      1      1      0
# 56003      8      1     32    472   2197     27      5      1      1      0
# 56036      8      2     32    472   2197     27      5      1      1      0
# 56069      8      3     32    472   2197     27      5      1      1      0
# 56102      8      4     32    472   2197     27      5      1      1      0
# 56135      8      5     32    472   2197     27      5      1      1      0
# 56168      8      6     32    472   2197     27      5      1      1      0
# 56201      8      7     32    472   2197     27      5      1      1      0
# 56233      8      8     32    472   2197     27      5      1      1      0
# 56265      8      9     32    472   2197     27      5      1      1      0
# 56297      8     10     32    472   2197     27      5      1      1      0
# 56329      8     11     32    472   2197     27      5      1      1      0
# 56361      8     12     32    472   2197     27      5      1      1      0
# 56393      8     13     32    472   2197     27      5      1      1      0
# 56425      8     14     32    472   2197     27      5      1      1      0
# 56457      8     15     32    472   2197     27      5      1      1      0
# 56490      8     16     32    472   2197     27      5      1      1      0
# 56523      8     17     32    472   2197     27      5      1      1      0
# 56556      8     18     32    472   2197     27      5      1      1      0
# 56589      8     19     32    472   2197     27      5      1      1      0
# 56622      8     20     32    472   2197     27      5      1      1      0
# 56655      8     21     32    472   2197     27      5      1      1      0
# 56688      8     22     32    472   2197     27      5      1      1      0
# 56722      8     23     32    472   2197     27      5      1      1      0
# 56756      8     24     32    472   2197     27      5      1      1      0
# 56789      8     25     32    472   2197     27      5      1      1      0
# 56822      8     26     32    472   2197     27      5      1      1      0
# 56855      8     27     32    472   2197     27      5      1      1      0
# 56888      8     28     32    472   2197     27      5      1      1      0
#
# [50 rows x 21 columns]

# %%
import numpy as np
from vpython import*
scene = canvas() # This is needed in Jupyter notebook and lab to make programs easily rerunnable
   
Db = 17
Dy = 3
DS = 500
Nw = 3
Ds = 30
Dw = 45
gap=(DS-(Nw-1)*Ds-Dw)/2.0
NStations = 46
Ocmax = 160

ycenter = 1127
scene.width = 800
scene.height = 200
scene.range = 40
scene.center = vector(ycenter,0,0)
scene.background = color.green
scene.ambient = color.gray(0.4)
scene.forward = vector(0,0.5,-1)
scene.up = vector(0,0,1)
scene.fov = 0.1
scene.lights[0].direction = vector(-10,10,10)



stationElements = []

#Estación Calle 100
posx = 1100
posst=vector(posx,-11,-1)
stationElements.append(box(pos=posst, length=DS, width=1,height=5, color=color.gray(0.8) ))
posst=vector(posx,11,-1)
stationElements.append(box(pos=posst, length=DS, width=1,height=5, color=color.gray(0.8) ))


# corredor
posx = 1127
posst=vector(posx,8,-1)
stationElements.append(box(pos=posst, length=5.5*Dw, width=1,height=10, color=color.gray(0.8) ))
posst=vector(posx,-8,-1)
stationElements.append(box(pos=posst, length=5.5*Dw, width=1,height=10, color=color.gray(0.8) ))

# vagón 1
posx = 1054
posv=vector(posx,0,0)
stationElements.append(box(pos=posv, length=Dw, width=10,height=10, color=color.blue))
#vagon 2
posx = 1127
posv=vector(posx,0,0)
stationElements.append(box(pos=posv, length=Dw, width=10,height=10, color=color.blue))
#vagón 3
posx = 1204
posv=vector(posx,0,0)
stationElements.append(box(pos=posv, length=Dw, width=10,height=10, color=color.blue))


#if j+1<Nw:
posv=vector(1127,0,0)
stationElements.append(box(pos=posv, length=4*Dw, width=1,height=6, color=color.blue))
#if j==0:
#    posst=vector(x-0.5*Dw,-8,-1)
#    stationElements.append(box(pos=posst, length=Dw, width=1,height=10, color=color.gray(0.8)))
#    posst=vector(x-0.5*Dw,8,-1)
#    stationElements.append(box(pos=posst, length=Dw, width=1,height=10, color=color.gray(0.8)))

buses = []
time0 = 2900
for time in range(time0,time0+3600):
    rate(10)
    
    for bus in buses:
        bus.visible = False
    del buses
        
    mask = df['tiempo']==time
    buses = []
    for index, bus in df[mask].iterrows():
        dire = bus['par17']
        if (dire == 0): # buses to the north
            x = bus['par0']
            y = bus['par1']
            lineid = bus['par10']
            DB = bus['par15']
            posbus = vector(x-0.5*DB,2*(2*y-5)-0.5*Dy,0)
            buses.append(box(pos=posbus, length=0.97*DB, height=Dy, width=4, color=vector(lineid/17,0.2,0.2)))
        else: # buses to the south
            x = 1536-bus['par0']+2250
            y = bus['par1']
            lineid = bus['par10']
            DB = bus['par15']
            posbus = vector(x+0.5*DB,-(2*(2*y-5)-0.5*Dy),0)
            buses.append(box(pos=posbus, length=0.97*DB, height=Dy, width=4, color=vector(lineid/17,0.2,0.2)))
    #scene.capture('optimo_pass_%d'%(time-time0))
# Out:
# <div id="glowscript" class="glowscript"></div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[56], line 72
#      70 time0 = 2900
#      71 for time in range(time0,time0+3600):
# ---> 72     rate(10)
#      74     for bus in buses:
#      75         bus.visible = False
#
# File U:\PyFiles\Envs\brtsim\Lib\site-packages\vpython\rate_control.py:266, in _RateKeeper2.__call__(self, N)
#     264 self.rval = N
#     265 if self.rval < 1: raise ValueError("rate value must be greater than or equal to 1")
# --> 266 super(_RateKeeper2, self).__call__(self.rval)
#
# File U:\PyFiles\Envs\brtsim\Lib\site-packages\vpython\rate_control.py:214, in RateKeeper.__call__(self, maxRate)
#     212 if self.whenToRender[self.renderIndex] == self.rateCount:
#     213     sleeps += 1
# --> 214     _sleep(self.interactionPeriod)
#     215 else:
#     216     break
#
# File U:\PyFiles\Envs\brtsim\Lib\site-packages\vpython\rate_control.py:62, in _sleep(dt)
#      60 dtsleep = nticks*_tick
#      61 t = _clock()
# ---> 62 time.sleep(dtsleep)
#      63 t = _clock()-t
#      64 dt -= t
#
# KeyboardInterrupt:

# %% [markdown]
# # Cosas a corregir:
# - Las rutas al sur hacen mucho zigzagging. El zigzagging se produce por la combinación de la posibilidad de pasar a la main lane si hay obstáculos, y la obligación de pasar a la stopping lane cuando el fin del carril es más importante.
# - También hacia el sur se nota cómo muchos buses que van a parar en el vagón 6 pasan a la stopping lane muy temprano, incluso teniendo obstáculos.
# - Es posible que con la regla actual, los buses haciendo fila en la stopping lane pasen a la main lane para adelantarse en la fila. Un posible arreglo a esta situación es el requerimiento de que para pasar a la main lane, no debe haber más de 1 bus de la misma ruta en la stopping lane antes de llegar a la estación.

# %%
df[df['tiempo']==5600]
# Out:
#         tiempo  par0  par1  par2  par3  par4  par5  par6     par7  par8  ...  \
# 209105    5600   100     0     0     0     0     0     0     1132     0  ...
# 209106    5600   128     0     7    42     0     0     0     1207     0  ...
# 209107    5600   128     1     7   283     0     0     0  1000000    -1  ...
# 209108    5600   202     0    12   186     0     0     0     1132     0  ...
# 209109    5600   410     0    17    92     0     0     0  1000000    -1  ...
# 209110    5600   431     1     0     0     0     0     0  1000000    -1  ...
# 209111    5600   458     1     0     0     0     0     0     1059     0  ...
# 209112    5600   485     1     0     0     0     0     0     1059     0  ...
# 209113    5600   512     1     0     0     0     0     0  1000000    -1  ...
# 209114    5600   529     0    17   209     0     0     0  1000000    -1  ...
# 209115    5600   539     1     0     0     0     0     0  1000000    -1  ...
# 209116    5600   566     1     0     0     0     0     0  1000000    -1  ...
# 209117    5600   593     1     0     0     0     0     0  1000000    -1  ...
# 209118    5600   620     1     0     0     0     0     0     1059     0  ...
# 209119    5600   647     1     0     0     0     0     0  1000000    -1  ...
# 209120    5600   674     1     0     0     0     0     0     1059     0  ...
# 209121    5600   701     1     0     0     0     0     0     1059     0  ...
# 209122    5600   728     1     0     6     0     0     0     1059     0  ...
# 209123    5600   755     0    17    85     0     0     0     1188     0  ...
# 209124    5600   765     1     4    20     0     0     0     1059     0  ...
# 209125    5600   808     1     0     0     0     0     0  1000000    -1  ...
# 209126    5600   835     1     0     1     0     0     0     1059     0  ...
# 209127    5600   853     1     0     0     0     0     0  1000000    -1  ...
# 209128    5600   857     0    17   370     0     0     0  1000000    -1  ...
# 209129    5600   880     1     0     0     0     0     0     1059     0  ...
# 209130    5600   897     1     0     0     0     0     0  1000000    -1  ...
# 209131    5600   924     1     0     0     0     0     0  1000000    -1  ...
# 209132    5600   951     1     0     0   259   -84    17     1059     0  ...
# 209133    5600   978     1     0     0   232  -111    17     1059     0  ...
# 209134    5600  1005     1     0     0   205  -138    17     1059     0  ...
# 209135    5600  1032     1     0     0   178  -165    17     1059     0  ...
# 209136    5600  1059     1     0    46  1000   -93    17  1000000    -1  ...
# 209137    5600  1132     1     0   118  1000     9     6  1000000    -1  ...
# 209138    5600  1254     0    17    46     0     0     0  1000000    -1  ...
# 209139    5600  1289     1    12    18     6   -13    17  1000000    -1  ...
# 209140    5600  1327     0    17    18     0     0     0  1000000    -1  ...
# 209141    5600  1372     0    17   946  1000   -81    17  1000000    -1  ...
# 209142    5600  2345     0    17    82     0     0     0     2681     1  ...
# 209143    5600  2454     0    17    71     0     0     0     2681     1  ...
# 209144    5600  2541     0     6     6    16 -1000     0     2681     1  ...
# 209145    5600  2575     0     7   147   -17 -1000     0     2753     1  ...
# 209146    5600  2578     1     0     0   137    17     6     2605     1  ...
# 209147    5600  2605     1     0   216  1000    18     0  1000000    -1  ...
# 209148    5600  2757     0    15   990  1000   -21     0  1000000    -1  ...
#
#         par10  par11  par12  par13  par14  par15  par16  par17  par18  par19
# 209105      2      0      0    497   5597     27      3      0      0      0
# 209106      0      0      0    499   5585     27      5      0      0      0
# 209107     15      0      0    488   5593     17      6      0      1      0
# 209108      3      0      0    438   5581     27      3      0      0      0
# 209109     17      0      0    487   5567     17      6      0      0      0
# 209110     15      0      0    437   5549     27      6      0      1      0
# 209111      5      0      0    453   5544     27      1      0      1      0
# 209112      6      0      0    446   5528     27      1      0      1      0
# 209113     15      0      0    491   5520     27      6      0      1      0
# 209114     17      0      0    449   5566     27      6      0      0      0
# 209115     15      0      0    464   5491     27      6      0      1      0
# 209116     15      0      0    485   5466     27      6      0      1      0
# 209117     15      0      0    473   5419     27      6      0      1      0
# 209118      6      0      0    439   5409     27      1      0      1      0
# 209119     15      0      0    447   5383     27      6      0      1      0
# 209120      6      0      0    459   5370     27      1      0      1      0
# 209121      6      0      0    492   5264     27      1      0      1      0
# 209122      5      0      0    472   5249     27      1      0      1      0
# 209123      1      0      0    471   5547     17      4      0      0      0
# 209124      5      0      0    483   5238     27      1      0      1      0
# 209125     15      0      0    484   5225     27      6      0      1      0
# 209126      5      0      0    450   5225     27      1      0      1      0
# 209127     15      0      0    489   5186     17      6      0      1      0
# 209128     17      0      0    465   5544     17      6      0      0      0
# 209129      5      0      0    444   5176     27      1      0      1      0
# 209130     15      0      0    468   5170     17      6      0      1      0
# 209131     15      0      0    469   5113     27      6      0      1      0
# 209132      5      0      0    440   5093     27      1      0      1      0
# 209133      5      0      0    461   4955     27      1      0      1      0
# 209134      6      0      0    448   4948     27      1      0      1      0
# 209135      6      0      0    467   4905     27      1      0      1      0
# 209136      6     20     51    443   4900     27      1      0      1      0
# 209137      2     14     29    490   5494     27      3      0      0      0
# 209138     17      0      0    475   5522     27      6      0      0      0
# 209139      4     33     33    436   5459     27      3      0      0      1
# 209140     17      0      0    474   5511     27      6      0      0      0
# 209141      5     32     32    456   4847     27      1      0      1      0
# 209142     11      0      0    481   5546     27      3      1      0      0
# 209143     10      0      0    476   5540     27      3      1      0      0
# 209144     11      0      0    478   5532     27      3      1      0      0
# 209145      8      0      0    466   5496     27      5      1      1      0
# 209146     12      0      0    477   5466     27      1      1      0      0
# 209147     13      9     37    442   5440     27      1      1      0      0
# 209148     13     38     38    493   5444     27      1      1      0      0
#
# [44 rows x 21 columns]

# %%
df[(df['par13']==481) & (df['tiempo']>5600)].head(20)
# Out:
#         tiempo  par0  par1  par2  par3  par4  par5  par6     par7  par8  ...  \
# 167229    6327   100     0     0     0     0     0     0  1000000    -1  ...
# 167271    6328   101     0     1    34     0     0     0  1000000    -1  ...
# 167312    6329   103     0     2    43     0     0     0  1000000    -1  ...
# 167353    6330   106     0     3    52     0     0     0  1000000    -1  ...
# 167394    6331   110     0     4    61     0     0     0  1000000    -1  ...
# 167435    6332   115     0     5    70     0     0     0  1000000    -1  ...
# 167476    6333   121     0     6    79     0     0     0  1000000    -1  ...
# 167517    6334   127     0     6    88     0     0     0  1000000    -1  ...
# 167558    6335   134     0     7    98     0     0     0  1000000    -1  ...
# 167598    6336   142     0     8   108     0     0     0  1000000    -1  ...
# 167638    6337   151     0     9   117     0     0     0  1000000    -1  ...
# 167678    6338   161     0    10   125     0     0     0  1000000    -1  ...
# 167717    6339   172     0    11   132     0     0     0  1000000    -1  ...
# 167756    6340   183     0    11   138     0     0     0  1000000    -1  ...
# 167795    6341   195     0    12   143     0     0     0  1000000    -1  ...
# 167834    6342   208     0    13   148     0     0     0  1000000    -1  ...
# 167873    6343   221     0    13   152     0     0     0  1000000    -1  ...
# 167912    6344   235     0    14   156     0     0     0  1000000    -1  ...
# 167951    6345   250     0    15   158     0     0     0  1000000    -1  ...
# 167990    6346   266     0    16   160     0     0     0  1000000    -1  ...
#
#         par10  par11  par12  par13  par14  par15  par16  par17  par18  par19
# 167229     17      0      0    481   6327     27      6      0      0      0
# 167271     17      0      0    481   6327     27      6      0      0      0
# 167312     17      0      0    481   6327     27      6      0      0      0
# 167353     17      0      0    481   6327     27      6      0      0      0
# 167394     17      0      0    481   6327     27      6      0      0      0
# 167435     17      0      0    481   6327     27      6      0      0      0
# 167476     17      0      0    481   6327     27      6      0      0      0
# 167517     17      0      0    481   6327     27      6      0      0      0
# 167558     17      0      0    481   6327     27      6      0      0      0
# 167598     17      0      0    481   6327     27      6      0      0      0
# 167638     17      0      0    481   6327     27      6      0      0      0
# 167678     17      0      0    481   6327     27      6      0      0      0
# 167717     17      0      0    481   6327     27      6      0      0      0
# 167756     17      0      0    481   6327     27      6      0      0      0
# 167795     17      0      0    481   6327     27      6      0      0      0
# 167834     17      0      0    481   6327     27      6      0      0      0
# 167873     17      0      0    481   6327     27      6      0      0      0
# 167912     17      0      0    481   6327     27      6      0      0      0
# 167951     17      0      0    481   6327     27      6      0      0      0
# 167990     17      0      0    481   6327     27      6      0      0      0
#
# [20 rows x 21 columns]

# %%
(1132-1097)<(2*27+2*6-27)
# Out:
# True

# %%
fig, ax = plt.subplots()
sns.scatterplot(df, x = 'tiempo', y = 'par0', hue = 'par1', ax = ax, size = 4)
#ax.set_xlim(2000,4000)
# Out:
# <Axes: xlabel='tiempo', ylabel='par0'>
# U:\PyFiles\Envs\brtsim\Lib\site-packages\IPython\core\events.py:82: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)

# %%
fig, ax = plt.subplots()
sns.scatterplot(df, x = 'tiempo', y = 'par0', hue = 'par1', ax = ax, size = 4)
#ax.set_xlim(2000,4000)
# Out:
# <Axes: xlabel='tiempo', ylabel='par0'>

# %%
df[df['par10']==15]['par15']
# Out:
# 0        27
# 1        27
# 2        27
# 3        27
# 5        27
#          ..
# 46320    27
# 46321    27
# 46327    27
# 46329    27
# 46335    27
# Name: par15, Length: 18231, dtype: int64
